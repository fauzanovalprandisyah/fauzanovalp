# %% [markdown]
# <a href="https://colab.research.google.com/github/fauzanovalprandisyah/fauzanovalp/blob/main/tugas_python14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def cos(frek,tipe,ht,hr,d):
  #frek = frekuensi (MHz)
  #tipe = urban, suburban, open
  #ht = tinggi tower (meter)
  #hr = tinggi user (meter)
  #d = jarak (meter)
    if frek in range(150,1501):
        Ca=69.55
        Cb=26.16
    elif frek in range(1501,2001):
        Ca=46.3
        Cb=33.9
    
    if tipe=='urban' :
        Cm=0
    elif tipe=='suburban' :
        Cm= -2*((np.log10((frek/28)**2))-5.4)
    elif tipe=='open' :
        Cm= -4.78*(np.log10(frek))+18.33*(np.log10(frek))-40.94
    else :
        Cm='tipe salah'
    
    ahr = (1.1*np.log10(frek)-0.7)*hr-(1.56*np.log10(frek)-1.8)
    Lp = Ca+(Cb*np.log10(frek))-(13.83*np.log(ht))-ahr+((44.9-6.55*np.log10(ht))*np.log10(d))-Cm
    
    return Lp

# %%
frek=1800 #MHz
atower=80 #m
auser=1.5 #m
dmin=300 #m
dmax=1000 #m
N=200 #titik
d=np.random.randint(dmin,dmax,N)

# %%
LpUrban=cos(frek, 'urban', atower, auser, d)
LpSuburban=cos(frek, 'suburban', atower, auser, d)
LpOpen=cos(frek, 'open', atower, auser, d)

# %%
d_sort=d[np.argsort(d)]
Urban_sort=LpUrban[np.argsort(d)]
Suburban_sort=LpSuburban[np.argsort(d)]
Open_sort=LpOpen[np.argsort(d)]

# %%
frek1= 700 #mhz
frek2= 900 #mhz
frek3= 1800 #mhz
loc= 'urban'
LpUrban1=cos(frek1, loc, atower, auser, d)
LpUrban2=cos(frek2, loc, atower, auser, d)
LpUrban3=cos(frek3, loc, atower, auser, d)

# %%
d_sort=d[np.argsort(d)]
Urban1_sort=LpUrban1[np.argsort(d)]
Urban2_sort=LpUrban2[np.argsort(d)]
Urban3_sort=LpUrban3[np.argsort(d)]

# %%
def daya_terima (pt,pl,gt,gx):
  #Ubah ke dBm
  ptx=10*np.log10(pt)

  #Hitung Daya Terima 
  prxl= ptx-pl+gt+gx

  #Ubah ke Miliwatt 
  prx=10**(prxl/10)

  return prx

# %%
pt=30000 #miliwatt
gt=10 #dB
gx=2 #dB

prxurban= daya_terima (pt,Urban_sort,gt,gx)
prxsuburban= daya_terima(pt,Suburban_sort,gt,gx)
prxopen= daya_terima(pt,Open_sort,gt,gx)

# %%
prxurban1= daya_terima(pt,Urban1_sort,gt,gx)
prxurban2= daya_terima(pt,Urban2_sort,gt,gx)
prxurban3= daya_terima(pt,Urban3_sort,gt,gx)

# %%
plt.figure()
plt.title("Daya Terima")
plt.plot(d_sort,prxurban, label = "urban")
plt.plot(d_sort,prxopen, label = "open")
plt.plot(d_sort,prxsuburban, label = "suburban")
plt.xlabel('Jarak (m)')
plt.ylabel('daya terima(miliwatt)')
plt.legend()
plt.show()

# %%
plt.figure()
plt.title("Daya Terima")
plt.plot(d_sort,prxurban1, label = "700 Mhz")
plt.plot(d_sort,prxurban2, label = "900 Mhz")
plt.plot(d_sort,prxurban3, label = "1800 Mhz")
plt.xlabel('Jarak (m)')
plt.ylabel('daya terima(miliwatt)')
plt.legend()
plt.show()

# %%
def hSNR (prx,BW):
  #Hitung Noise
  Noise1= -174+(10*np.log10(BW))

  #Ubah Noise 
  Noise= 10**(Noise1/10)

  #Hitung SNR
  SNR= prx/Noise

  return SNR

# %%
BW=5000000 #hz
SNRurban= hSNR (prxurban,BW)
SNRsuburban= hSNR(prxsuburban,BW)
SNRopen= hSNR(prxopen,BW)

# %%
SNRurban1 = hSNR(prxurban1,BW)
SNRurban2 = hSNR(prxurban2,BW)
SNRurban3 = hSNR(prxurban3,BW)

# %%
plt.figure()
plt.title("SNR")
plt.plot(d_sort,SNRurban, label = "urban")
plt.plot(d_sort,SNRopen, label = "open")
plt.plot(d_sort,SNRsuburban, label = "suburban")
plt.xlabel('Jarak (m)')
plt.ylabel('SNR(dB)')
plt.legend()
plt.show()

# %%
plt.figure()
plt.title("SNR")
plt.plot(d_sort,SNRurban1, label = "700 Mhz")
plt.plot(d_sort,SNRurban2, label = "900 Mhz")
plt.plot(d_sort,SNRurban3, label = "1800 Mhz")
plt.xlabel('Jarak (m)')
plt.ylabel('SNR(dB)')
plt.legend()
plt.show()
